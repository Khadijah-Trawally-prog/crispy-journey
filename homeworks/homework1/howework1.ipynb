# %%
import numpy as np
import pandas as pd

# %%
# reading data
df = pd.read_csv('car_fuel_efficiency.csv')
df
# Out:
#       engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 0                     170            3.0       159.0     3413.433759
# 1                     130            5.0        97.0     3149.664934
# 2                     170            NaN        78.0     3079.038997
# 3                     220            4.0         NaN     2542.392402
# 4                     210            1.0       140.0     3460.870990
# ...                   ...            ...         ...             ...
# 9699                  140            5.0       164.0     2981.107371
# 9700                  180            NaN       154.0     2439.525729
# 9701                  220            2.0       138.0     2583.471318
# 9702                  230            4.0       177.0     2905.527390
# 9703                  270            3.0       140.0     2908.043477
#
#       acceleration  model_year  origin fuel_type         drivetrain  \
# 0             17.7        2003  Europe  Gasoline    All-wheel drive
# ...

# %%
#How many records are in the dataset?
print('Answer')
len(df)
# Out:
# Answer
# 9704

# %%
# counting the number of records for each column 
df.count()
# Out:
# engine_displacement    9704
# num_cylinders          9222
# horsepower             8996
# vehicle_weight         9704
# acceleration           8774
# model_year             9704
# origin                 9704
# fuel_type              9704
# drivetrain             9704
# num_doors              9202
# fuel_efficiency_mpg    9704
# dtype: int64

# %%
# Getting the information about the data frame 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9704 entries, 0 to 9703
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   engine_displacement  9704 non-null   int64
#  1   num_cylinders        9222 non-null   float64
#  2   horsepower           8996 non-null   float64
#  3   vehicle_weight       9704 non-null   float64
#  4   acceleration         8774 non-null   float64
#  5   model_year           9704 non-null   int64
#  6   origin               9704 non-null   object
#  7   fuel_type            9704 non-null   object
#  8   drivetrain           9704 non-null   object
#  9   num_doors            9202 non-null   float64
#  10  fuel_efficiency_mpg  9704 non-null   float64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 834.1+ KB

# %%
#How many fuel types are presented in the dataset?
print('Answer')
df['fuel_type'].nunique()
# Out:
# Answer
# 2

# %%
#How many columns in the dataset have missing values?
print('Answer')
print(df.isnull().any().sum())
# Out:
# Answer
# 4

# %%
#What's the maximum fuel efficiency of cars from Asia?
print('Answer')
df_asia = df[df['origin'] == 'Asia']
print(round(df_asia['fuel_efficiency_mpg'].max(), 2))

#efficient implementation 
print(round(df[df['origin'] == 'Asia']['fuel_efficiency_mpg'].max(), 2))
# Out:
# Answer
# 23.76
# 23.76

# %% [markdown]
# ## Q6. Median value of horsepower
#
# 1. Find the median value of the `horsepower` column in the dataset.
# 2. Next, calculate the most frequent value of the same `horsepower` column.
# 3. Use the `fillna` method to fill the missing values in the `horsepower` column with the most frequent value from the previous step.
# 4. Now, calculate the median value of `horsepower` once again.
#
# Has it changed?
#
#
# - Yes, it increased
# - Yes, it decreased
# - No

# %%
print(round(df['horsepower'].mean(), 2))
print(round(df['horsepower'].median(), 2))
# Out:
# 149.66
# 149.0

# %%
df1 = df.copy()
# Out:
#       engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 0                     170            3.0       159.0     3413.433759
# 1                     130            5.0        97.0     3149.664934
# 2                     170            NaN        78.0     3079.038997
# 3                     220            4.0         NaN     2542.392402
# 4                     210            1.0       140.0     3460.870990
# ...                   ...            ...         ...             ...
# 9699                  140            5.0       164.0     2981.107371
# 9700                  180            NaN       154.0     2439.525729
# 9701                  220            2.0       138.0     2583.471318
# 9702                  230            4.0       177.0     2905.527390
# 9703                  270            3.0       140.0     2908.043477
#
#       acceleration  model_year  origin fuel_type         drivetrain  \
# 0             17.7        2003  Europe  Gasoline    All-wheel drive
# ...

# %%
print(df1['horsepower'].mode())
# Out:
# 0    152.0
# Name: horsepower, dtype: float64

# %%
# df1 = df1.fillna( 152.0)
df1
# Out:
#       engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 0                     170            3.0       159.0     3413.433759
# 1                     130            5.0        97.0     3149.664934
# 2                     170          152.0        78.0     3079.038997
# 3                     220            4.0       152.0     2542.392402
# 4                     210            1.0       140.0     3460.870990
# ...                   ...            ...         ...             ...
# 9699                  140            5.0       164.0     2981.107371
# 9700                  180          152.0       154.0     2439.525729
# 9701                  220            2.0       138.0     2583.471318
# 9702                  230            4.0       177.0     2905.527390
# 9703                  270            3.0       140.0     2908.043477
#
#       acceleration  model_year  origin fuel_type         drivetrain  \
# 0             17.7        2003  Europe  Gasoline    All-wheel drive
# ...

# %%
print(round(df1['horsepower'].median(), 2))
# Out:
# 152.0
